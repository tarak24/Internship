# %% [markdown]
# # WEB SCRAPING ASSIGNMENT 4

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver.exe")
# Out:
# <ipython-input-174-0af43046ad15>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver.exe")

# %% [markdown]
# ## Q1

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
rank=[]
name=[]
uploader=[]
views=[]
date=[]

# %%
title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[1]")
for i in title_tag:
    try:
        rank.append(i.text)
    except:
        rank.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[2]")
for i in title_tag:
    try:
        name.append(i.text)
    except:
        name.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[3]")
for i in title_tag:
    try:
        uploader.append(i.text)
    except:
        uploader.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[4]")
for i in title_tag:
    try:
        views.append(i.text)
    except:
        views.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[5]")
for i in title_tag:
    try:
        date.append(i.text)
    except:
        date.append('-')
# Out:
# <ipython-input-21-b4885e9a9ede>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[1]")
# <ipython-input-21-b4885e9a9ede>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[2]")
# <ipython-input-21-b4885e9a9ede>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[3]")
# <ipython-input-21-b4885e9a9ede>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[4]")
# ...

# %%
you=pd.DataFrame({})
you['Rank']=rank
you['Name']=name
you['Uploader']=uploader
you['Views(in Billions)']=views
you['Date']=date
you
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[5]
# 2    3.                       "Johny Johny Yes Papa"[11]
# 3    4.                               "Shape of You"[12]
# 4    5.                              "See You Again"[14]
# 5    6.                                  "Bath Song"[19]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[20]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[21]
# 8    9.                                "Uptown Funk"[22]
# 9   10.                "Phonics Song with Two Words"[23]
# 10  11.                              "Gangnam Style"[24]
# 11  12.                             "Dame Tu Cosita"[29]
# 12  13.                                      "Sugar"[30]
# 13  14.                                      "Sorry"[31]
# 14  15.                                       "Roar"[32]
# ...

# %% [markdown]
# ## Q2

# %%
driver.get('https://www.bcci.tv/')

# %%
#Reaching International page
search_btn=driver.find_element_by_xpath("//*[@id='navigation']/ul[1]/li[2]/a")
search_btn.click()
# Out:
# <ipython-input-56-eb9ae7032461>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='navigation']/ul[1]/li[2]/a")

# %%
driver.get(driver.current_url)

# %%
#Reaching All Teams
search_btn=driver.find_element_by_xpath("//*[@id='fixtures']/div[2]/div/div[3]/div/div[1]")
search_btn.click()
# Out:
# <ipython-input-59-bba3f8431d7b>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='fixtures']/div[2]/div/div[3]/div/div[1]")

# %%
#Reaching India
search_btn=driver.find_element_by_xpath("//*[@id='fixtures']/div[2]/div/div[3]/div/div[2]/div[5]")
search_btn.click()
# Out:
# <ipython-input-60-bdf164a1bbfe>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='fixtures']/div[2]/div/div[3]/div/div[2]/div[5]")

# %%
title1=[]
title=[]
series=[]
place=[]
date=[] 
time=[]

# %%
title_tag=driver.find_elements_by_xpath("//*[@id='fixtures']/div[3]/div/div/div/div[3]/div")
for i in title_tag:
    try:
        title1.append(i.text)
    except:
        title1.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='fixtures']/div[3]/div/div/div/div[1]/h5[2]/span")
for i in title_tag:
    try:
        series.append(i.text)
    except:
        series.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='fixtures']/div[3]/div/div/div/div[1]/div/div[2]/h5")
for i in title_tag:
    try:
        time.append(i.text)
    except:
        time.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='fixtures']/div[3]/div/div/div/div[1]/div/div[1]/h5")
for i in title_tag:
    try:
        date.append(i.text)
    except:
        date.append('-')
# Out:
# <ipython-input-62-e9ddf84709cf>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='fixtures']/div[3]/div/div/div/div[3]/div")
# <ipython-input-62-e9ddf84709cf>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='fixtures']/div[3]/div/div/div/div[1]/h5[2]/span")
# <ipython-input-62-e9ddf84709cf>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='fixtures']/div[3]/div/div/div/div[1]/div/div[2]/h5")
# <ipython-input-62-e9ddf84709cf>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='fixtures']/div[3]/div/div/div/div[1]/div/div[1]/h5")

# %%
#Seperating Match title and place into 2 different lists.
for i in title1:
    t=i.split(' - ')
    title.append(t[0])
    place.append(t[1])

# %%
mat=pd.DataFrame({})
mat['Match Title']=title
mat['Series']=series
mat['Place']=place
mat['Date']=date
mat['Time']=time
mat
# Out:
#   Match Title                                          Series  \
# 0    2nd Test  INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22
# 1    3rd Test  INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22
# 2     1st ODI   INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 3     2nd ODI   INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 4     3rd ODI   INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
#
#                                  Place         Date         Time
# 0  The Wanderers Stadium, Johannesburg   3 JAN 2022  1:30 PM IST
# 1                  Newlands, Cape Town  11 JAN 2022  2:00 PM IST
# 2                   Boland Park, Paarl  19 JAN 2022  2:00 PM IST
# 3                   Boland Park, Paarl  21 JAN 2022  2:00 PM IST
# 4                  Newlands, Cape Town  23 JAN 2022  2:00 PM IST

# %% [markdown]
# ## Q3

# %%
driver.get('https://www.guru99.com/')

# %%
#Reaching Selenium Page
search_btn=driver.find_element_by_xpath("//*[@id='kt-info-box_eaeb48-11']/a/div[2]/h5")
search_btn.click()
# Out:
# <ipython-input-41-6a85940c3e86>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='kt-info-box_eaeb48-11']/a/div[2]/h5")

# %%
driver.get(driver.current_url)

# %%
#Reaching to selenium exception handling page
search_btn=driver.find_element_by_xpath("//*[@id='post-193']/div/div/table[5]/tbody/tr[34]/td[1]/a")
search_btn.click()
# Out:
# <ipython-input-43-17939d35d515>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='post-193']/div/div/table[5]/tbody/tr[34]/td[1]/a")

# %%
driver.get(driver.current_url)

# %%
name=[]
desc=[]

# %%
title_tag=driver.find_elements_by_xpath("//*[@id='post-1953']/div/div/table/tbody/tr/td[1]")
for i in title_tag:
    try:
        name.append(i.text)
    except:
        name.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='post-1953']/div/div/table/tbody/tr/td[2]")
for i in title_tag:
    try:
        desc.append(i.text)
    except:
        desc.append('-')
# Out:
# <ipython-input-46-d9bc7e834ff8>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='post-1953']/div/div/table/tbody/tr/td[1]")
# <ipython-input-46-d9bc7e834ff8>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='post-1953']/div/div/table/tbody/tr/td[2]")

# %%
name=name[1:]
desc=desc[1:]

# %%
exp=pd.DataFrame({})
exp['Name']=name
exp['Description']=desc
exp
# Out:
#                                    Name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# ...

# %% [markdown]
# ## Q4

# %%
driver.get('http://statisticstimes.com/')

# %%
from selenium.webdriver import ActionChains
source= driver.find_element_by_xpath("//*[@id='top']/div[2]/div[2]/button");
# action chain object creation
action = ActionChains(driver)
# move to the element and click then perform the operation
action.move_to_element(source).click().perform()
# Out:
# <ipython-input-176-22f63543ee71>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   source= driver.find_element_by_xpath("//*[@id='top']/div[2]/div[2]/button");

# %%
#Reaching Economy of country
search_btn=driver.find_element_by_xpath("//*[@id='top']/div[2]/div[2]/div/a[2]")
search_btn.click()
# Out:
# <ipython-input-177-047e9a377fc6>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='top']/div[2]/div[2]/div/a[2]")

# %%
driver.get(driver.current_url)

# %%
#Reaching GDP of India
search_btn=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[3]/ul/li[79]/a")
search_btn.click()
# Out:
# <ipython-input-179-085de70b75b3>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[3]/ul/li[79]/a")

# %%
driver.get(driver.current_url)

# %%
#Reaching more economic stats
search_btn=driver.find_element_by_xpath("//*[@id='main']/div[2]/div[5]/ul/li[6]/a")
search_btn.click()
# Out:
# <ipython-input-181-90ea4cc7fcb3>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='main']/div[2]/div[5]/ul/li[6]/a")

# %%
driver.get(driver.current_url)

# %%
#Reaching statewise gdp
search_btn=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
search_btn.click()
# Out:
# <ipython-input-183-d5222de2ea05>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")

# %%
driver.get(driver.current_url)

# %%
rank=[]
state=[]
gsdp20=[]
gsdp19=[]
share=[]
gdp=[]

# %%
title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[1]")
for i in title_tag:
    try:
        rank.append(i.text)
    except:
        rank.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[2]")
for i in title_tag:
    try:
        state.append(i.text)
    except:
        state.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[3]")
for i in title_tag:
    try:
        gsdp20.append(i.text)
    except:
        gsdp20.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[4]")
for i in title_tag:
    try:
        gsdp19.append(i.text)
    except:
        gsdp19.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[5]")
for i in title_tag:
    try:
        share.append(i.text)
    except:
        share.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[6]")
for i in title_tag:
    try:
        gdp.append(i.text)
    except:
        gdp.append('-')
# Out:
# <ipython-input-186-374f95dbd9a3>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[1]")
# <ipython-input-186-374f95dbd9a3>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[2]")
# <ipython-input-186-374f95dbd9a3>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[3]")
# <ipython-input-186-374f95dbd9a3>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr/td[4]")
# ...

# %%
ind=pd.DataFrame({})
ind['Rank']=rank
ind['State']=state
ind['GSDP(19-20)']=gsdp20
ind['GSDP(18-19)']=gsdp19
ind['Share']=share
ind['GDP($ billion)']=gdp
ind
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19)   Share  \
# 0     1                Maharashtra           -   2,632,792  13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%
# 3     4                    Gujarat           -   1,502,899   7.96%
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%
# 5     6                West Bengal   1,253,832   1,089,898   5.77%
# 6     7                  Rajasthan   1,020,989     942,586   4.99%
# 7     8             Andhra Pradesh     972,782     862,957   4.57%
# 8     9                  Telangana     969,604     861,031   4.56%
# 9    10             Madhya Pradesh     906,672     809,592   4.29%
# 10   11                     Kerala           -     781,653   4.14%
# 11   12                      Delhi     856,112     774,870   4.10%
# 12   13                    Haryana     831,610     734,163   3.89%
# ...

# %% [markdown]
# ## Q5

# %%
driver.get('https://github.com/')

# %%
#Navigating Explore element
from selenium.webdriver import ActionChains
# identifying the source element
source= driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary");
# action chain object creation
action = ActionChains(driver)
# move to the element and click then perform the operation
action.move_to_element(source).click().perform()
# Out:
# <ipython-input-202-15e7c19e7cdf>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   source= driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary");

# %%
#Reaching Trending page
search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
search_btn.click()
# Out:
# <ipython-input-203-3c742d6690c5>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")

# %%
driver.get(driver.current_url)

# %%
title=[]
des=[]
con=[]
lan=[]

# %%
title_tag=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/h1/a")
for i in title_tag:
    try:
        title.append(i.text)
    except:
        title.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/p")
for i in title_tag:
    try:
        des.append(i.text)
    except:
        des.append('-')
des.insert(-7,'-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/div[2]/a[2]")
for i in title_tag:
    try:
        con.append(i.text)
    except:
        con.append('-')
        
title_tag=driver.find_elements_by_xpath(f"//span[@itemprop='programmingLanguage']")
for i in title_tag:
    try:
        lan.append(i.text)
    except:
        lan.append('-')
lan.insert(1,'-')
lan.insert(5,'-')
lan.insert(6,'-')
lan.insert(7,'-')
lan.insert(14,'-')
# Out:
# <ipython-input-227-5b351934abc9>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/h1/a")
# <ipython-input-227-5b351934abc9>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/p")
# <ipython-input-227-5b351934abc9>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/div[2]/a[2]")
# <ipython-input-227-5b351934abc9>:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath(f"//span[@itemprop='programmingLanguage']")

# %%
git=pd.DataFrame({})
git['Repository title']=title
git['Repository description']=des
git['Contributors count']=con
git['Languages used']=lan
git
# Out:
#                                Repository title  \
# 0                      teslamotors / light-show
# 1             youngyangyang04 / leetcode-master
# 2            donnemartin / system-design-primer
# 3                  Courseplay / Courseplay_FS22
# 4                             bitcoin / bitcoin
# 5                        sindresorhus / awesome
# 6                       R2Northstar / Northstar
# 7         mtdvio / every-programmer-should-know
# 8              trekhleb / javascript-algorithms
# 9                        alesimula / wsa_pacman
# 10                    mpcabete / bombcrypto-bot
# 11  Hackmanit / Web-Cache-Vulnerability-Scanner
# 12                        babysor / MockingBird
# 13                           Tinkoff / taiga-ui
# 14                             mkrl / misbrands
# 15              30-seconds / 30-seconds-of-code
# 16                            notthebee / infra
# 17                        bangle-io / bangle-io
# ...

# %% [markdown]
# ## Q6

# %%
driver.get('https:/www.billboard.com/')

# %%
#Reaching Charts page
from selenium.common.exceptions import ElementNotInteractableException

try:
    elem = driver.find_element_by_xpath("//*[@id='main-wrapper']/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a")
    elem.click()
except ElementNotInteractableException:  #spelling error making this code not work as expected
    elem = driver.find_element_by_xpath("//*[@id='main-wrapper']/header/div[1]/div/div/div[1]/button/svg")
    elem.click()
# Out:
# <ipython-input-80-6c558b764077>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath("//*[@id='main-wrapper']/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a")

# %%
driver.get(driver.current_url)

# %%
#Reaching hot 100-page
elem = driver.find_element_by_xpath("//*[@id='main-wrapper']/main/div[2]/div[1]/div[1]/div/div[1]/div[1]/div[2]/span/a")
elem.click()
# Out:
# <ipython-input-82-dccffce01326>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath("//*[@id='main-wrapper']/main/div[2]/div[1]/div[1]/div/div[1]/div[1]/div[2]/span/a")

# %%
driver.get(driver.current_url)

# %%
song_name=[]
art_name=[]
las_we_rank=[]
peak_rank=[]
we_on_board=[]

# %%
title_tag=driver.find_elements_by_xpath("//*[@id='title-of-a-story']")
for i in title_tag:
    try:
        song_name.append(i.text)
    except:
        song_name.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='post-1479786']/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[1]/span")
for i in title_tag:
    try:
        art_name.append(i.text)
    except:
        art_name.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='post-1479786']/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[4]/span")
for i in title_tag:
    try:
        las_we_rank.append(i.text)
    except:
        las_we_rank.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='post-1479786']/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[5]/span")
for i in title_tag:
    try:
        peak_rank.append(i.text)
    except:
        peak_rank.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='post-1479786']/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[6]/span")
for i in title_tag:
    try:
        we_on_board.append(i.text)
    except:
        we_on_board.append('-')
# Out:
# <ipython-input-90-131215804d95>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='title-of-a-story']")
# <ipython-input-90-131215804d95>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='post-1479786']/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[1]/span")
# <ipython-input-90-131215804d95>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='post-1479786']/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[4]/span")
# <ipython-input-90-131215804d95>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='post-1479786']/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[5]/span")
# ...

# %%
song_name=song_name[6:-16:4]

# %%
bill=pd.DataFrame({})
bill['Song Name']=song_name
bill['Artist Name']=art_name
bill['Last week rank']=las_we_rank
bill['Peak Rank']=peak_rank
bill['Weeks on board']=we_on_board
bill
# Out:
#                             Song Name                           Artist Name  \
# 0     All I Want For Christmas Is You                          Mariah Carey
# 1   Rockin' Around The Christmas Tree                            Brenda Lee
# 2                          Easy On Me                                 Adele
# 3                    Jingle Bell Rock                           Bobby Helms
# 4             A Holly Jolly Christmas                             Burl Ives
# ..                                ...                                   ...
# 95                            No Love                   Summer Walker & SZA
# 96          Bad Man (Smooth Criminal)                                Polo G
# 97                         Feel Alone                            Juice WRLD
# 98                      Heart On Fire                           Eric Church
# 99                             Bubbly  Young Thug With Drake & Travis Scott
#
#    Last week rank Peak Rank Weeks on board
# ...

# %% [markdown]
# ## Q7

# %%
driver.get('https://www.naukri.com/')

# %%
#Reaching Recruiters page
elem = driver.find_element_by_xpath("//*[@id='root']/div[1]/div/ul[1]/li[2]/a/div")
elem.click()
# Out:
# <ipython-input-190-5ee842ccfa02>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath("//*[@id='root']/div[1]/div/ul[1]/li[2]/a/div")

# %%
driver.switch_to.window(driver.window_handles[1])

# %%
search_job=driver.find_element_by_xpath("//*[@id='skill']/div[1]/div[2]/input")
search_job.send_keys("Data science")
# Out:
# <ipython-input-192-38ce803bdc40>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("//*[@id='skill']/div[1]/div[2]/input")

# %%
elem = driver.find_element_by_xpath("//*[@id='qsbFormBtn']")
elem.click()
# Out:
# <ipython-input-193-ebe35f99df5a>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath("//*[@id='qsbFormBtn']")

# %%
name=[]
desig=[]
comp=[]
skill=[]
loc=[]

# %%
title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/a[1]/span")
for i in title_tag:
    try:
        name.append(i.text)
    except:
        name.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/span[1]")
for i in title_tag:
    try:
        desig.append(i.text)
    except:
        desig.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/a[2]")
for i in title_tag:
    try:
        comp.append(i.text)
    except:
        comp.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[2]")
for i in title_tag:
    try:
        skill.append(i.text)
    except:
        skill.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/span[2]/small")
for i in title_tag:
    try:
        loc.append(i.text)
    except:
        loc.append('-')
        
loc.insert(28,'-')
loc.insert(47,'-')
# Out:
# <ipython-input-195-2cc5f1408d1d>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/a[1]/span")
# <ipython-input-195-2cc5f1408d1d>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/span[1]")
# <ipython-input-195-2cc5f1408d1d>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/a[2]")
# <ipython-input-195-2cc5f1408d1d>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[2]")
# ...

# %%
jo=pd.DataFrame({})
jo['Name']=name
jo['Designation']=desig
jo['Company']=comp
jo['Skills they hire for']=skill
jo['Location']=loc
jo
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %% [markdown]
# ## Q8

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/')

# %% [markdown]
# ![Capre.PNG](attachment:Capre.PNG)

# %% [markdown]
# ### The link in the assignment is giving an error page. Hence, leaving this question and I have raised ticket also.

# %% [markdown]
# ## Q9

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
name=[]
year=[]
genre=[]
runtime=[]
rating=[]
votes=[]

# %%
title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/h3/a")
for i in title_tag:
    try:
        name.append(i.text)
    except:
        name.append('-')

title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/h3/span[2]")
for i in title_tag:
    try:
        year.append(i.text)
    except:
        year.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/p[1]/span[5]")
for i in title_tag:
    try:
        genre.append(i.text)
    except:
        genre.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/p[1]/span[3]")
for i in title_tag:
    try:
        runtime.append(i.text)
    except:
        runtime.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/div[1]/div[1]/span[2]")
for i in title_tag:
    try:
        rating.append(i.text)
    except:
        rating.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/p[4]/span[2]")
for i in title_tag:
    try:
        votes.append(i.text)
    except:
        votes.append('-')
# Out:
# <ipython-input-131-d6ace28f79c0>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/h3/a")
# <ipython-input-131-d6ace28f79c0>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/h3/span[2]")
# <ipython-input-131-d6ace28f79c0>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/p[1]/span[5]")
# <ipython-input-131-d6ace28f79c0>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/p[1]/span[3]")
# ...

# %%
tv=pd.DataFrame({})
tv['Name']=name
tv['Year span']=year
tv['Genre']=genre
tv['Runtime']=runtime
tv['Ratings']=rating
tv['Votes']=votes
tv
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     Runtime Ratings      Votes
# 0    57 min     9.2  1,919,705
# ...

# %% [markdown]
# ## Q10

# %%
driver.get('https://archive.ics.uci.edu/')

# %%
#Reaching All datasets page
elem = driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
elem.click()
# Out:
# <ipython-input-134-051609f1dde0>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")

# %%
driver.get(driver.current_url)

# %%
name=[]
dtype=[]
task=[]
attr=[]
noi=[]
noa=[]
year=[]

# %%
title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
for i in title_tag:
    try:
        name.append(i.text)
    except:
        name.append('-')
        
title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p")
for i in title_tag:
    try:
        dtype.append(i.text)
    except:
        dtype.append('-')
        
title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p")
for i in title_tag:
    try:
        task.append(i.text)
    except:
        task.append('-')
        
title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p")
for i in title_tag:
    try:
        attr.append(i.text)
    except:
        attr.append('-')
        
title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p")
for i in title_tag:
    try:
        noi.append(i.text)
    except:
        noi.append('-')
        
title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p")
for i in title_tag:
    try:
        noa.append(i.text)
    except:
        noa.append('-')
        
title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p")
for i in title_tag:
    try:
        year.append(i.text)
    except:
        year.append('-')
# Out:
# <ipython-input-137-d980779a6db0>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
# <ipython-input-137-d980779a6db0>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p")
# <ipython-input-137-d980779a6db0>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p")
# <ipython-input-137-d980779a6db0>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ...

# %%
dtype=dtype[1:]
task=task[1:]
attr=attr[1:]
noi=noi[1:]
noa=noa[1:]
year=year[1:]

# %%
df=pd.DataFrame({})
df['Dataset name']=name
df['Data type']=dtype
df['Task']=task
df['Attribute type']=attr
df['No of instances']=noi
df['No of attribute']=noa
df['Year']=year
df
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %% [markdown]
# ## ****** END ******
