# %% [markdown]
# # E-retail factors for customer activation and retention: A case study from Indian e-commerce customers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## Importing Dataset

# %%
df=pd.read_csv('C:\\Users\\DELL\\Desktop\\Internship\\cust_ret.csv')
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                                                                                                                                                                  object
# 2 How old are you?                                                                                                                                                                                                     object
# 3 Which city do you shop online from?                                                                                                                                                                                  object
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                   int64
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.nunique()
# Out:
# 1Gender of respondent                                                                                                                                                                                                   2
# 2 How old are you?                                                                                                                                                                                                      5
# 3 Which city do you shop online from?                                                                                                                                                                                  11
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  39
# ...

# %%
#from sklearn.preprocessing import LabelEncoder
#label_encoder = LabelEncoder()
#t=list(df.columns)
#count=0
#for i in t:
    #count=count+1
    #print(count)
    #print(df[i].unique())
    #df[i]= label_encoder.fit_transform(df[i])
    #print(df[i].unique())
    #print('\n')

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Univariate Analysis

# %%
t=list(df.columns)
t.remove('3 Which city do you shop online from?')
t.remove('4 What is the Pin Code of where you shop online from?')
t=t[47:]
for i in t:
    plt.figure(figsize=(6,6))
    df[i].value_counts().plot.pie(autopct='%1.1f%%')
    centre=plt.Circle((0,0),0.7,fc='white')
    fig=plt.gcf()
    fig.gca().add_artist(centre)
    plt.xlabel(i)
    plt.ylabel('')
    plt.figure()

# %% [markdown]
# ### Amazon, Flipkart have been had the highest votes for having all the positive points and have maintained a very good brand image followed by paytm and the myntra.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ## Analysis with respective gender

# %%
wrt_gender=['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
           '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ','16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',
           '17 Why did you abandon the ?Bag?, ?Shopping Cart??\t\t\t\t\t                                                                                                                                                       ','31 Enjoyment is derived from shopping online','39 Offering a wide variety of listed product in several category',
           'Easy to use website or application','Perceived Trustworthiness','Which of the Indian online retailer would you recommend to a friend?']
for i in wrt_gender:
    plt.figure(figsize=(13,6))
    sns.countplot(df[i],hue=df['1Gender of respondent'])
    plt.xticks(rotation=35)

# %% [markdown]
# ## Analysis with respective Age

# %%
wrt_age=['6 How many times you have made an online purchase in the past 1 year?','14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
           '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ','16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',
           '17 Why did you abandon the ?Bag?, ?Shopping Cart??\t\t\t\t\t                                                                                                                                                       ',
           '31 Enjoyment is derived from shopping online',
           'Easy to use website or application','Perceived Trustworthiness','Which of the Indian online retailer would you recommend to a friend?']
for i in wrt_gender:
    plt.figure(figsize=(13,6))
    sns.countplot(df[i],hue=df['2 How old are you? '])
    plt.xticks(rotation=35)

# %% [markdown]
# ## Performance Analysis of Websites

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['47 Getting value for money spent'],
               hue=df['Which of the Indian online retailer would you recommend to a friend?'])
# Out:
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %% [markdown]
# ### In  Amazon, Flipkart and Myntra websites, customers are getting value to their money.

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['40 Provision of complete and relevant product information'],
               hue=df['Complete, relevant description information of products'])
# Out:
# <AxesSubplot:xlabel='40 Provision of complete and relevant product information', ylabel='count'>

# %% [markdown]
# ### In Amazon, Flipkart and Myntra websites, customers are getting complete information about the product.

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['23 Loading and processing speed'],
               hue=df['Fast loading website speed of website and application'])
# Out:
# <AxesSubplot:xlabel='23 Loading and processing speed', ylabel='count'>

# %% [markdown]
# ### Customers feel that the loading speed of Amazon, Flipkart, Myntra and Paytm websites are high.

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['28 Being able to guarantee the privacy of the customer'],
               hue=df['Privacy of customers? information'])
# Out:
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %% [markdown]
# ### Amazon and Flipkart are providing provides better privacy than other websites

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'],
               hue=df['Perceived Trustworthiness'])
# Out:
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %% [markdown]
# ### Customers feel that Amazon, Flipkart, Myntra and Snapdeal are trustworthy websites.

# %%
df['6 How many times you have made an online purchase in the past 1 year?'].unique()
# Out:
# array(['31-40 times', '41 times and above', 'Less than 10 times',
#        '11-20 times', '21-30 times', '42 times and above'], dtype=object)

# %%
dict={'31-40 times':35, '41 times and above':45, 'Less than 10 times':8,
       '11-20 times':15, '21-30 times':25, '42 times and above':45}
df['6 How many times you have made an online purchase in the past 1 year?']=df['6 How many times you have made an online purchase in the past 1 year?'].replace(dict)

# %%
df['3 Which city do you shop online from?'].unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
df['3 Which city do you shop online from?'].replace({'Greater Noida':'Noida'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.stripplot(df['3 Which city do you shop online from?'],df['6 How many times you have made an online purchase in the past 1 year?'],hue=df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='6 How many times you have made an online purchase in the past 1 year?'>

# %% [markdown]
# ### Male Customers living in Delhi and Noida are frequently shopping online.
# ### Female Customers living in all given cities except Moradabad and Bulandshahr are frequently shopping online.

# %%
df.drop(['3 Which city do you shop online from?','4 What is the Pin Code of where you shop online from?'],
       axis=1,inplace=True)

# %%
x=df.drop('Which of the Indian online retailer would you recommend to a friend?',axis=1)
y=df['Which of the Indian online retailer would you recommend to a friend?']

# %% [markdown]
# ## Encoding

# %%
x.drop(['6 How many times you have made an online purchase in the past 1 year?'],axis=1,inplace=True)

# %%
lis=list(x.columns)
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder
ordi=OrdinalEncoder()
for i in lis:
    x[i]=ordi.fit_transform(x[i].values.reshape(-1,1))

# %%
x['How many times you have made an online purchase in the past 1 year?']=df['6 How many times you have made an online purchase in the past 1 year?']

# %%
label=LabelEncoder()
y=label.fit_transform(y)

# %% [markdown]
# ## Scalling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0               1.434161            -0.280013
# 1              -0.697272            -1.126343
# 2              -0.697272            -1.126343
# 3               1.434161            -1.126343
# 4              -0.697272            -1.126343
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                    0.576221
# 1                                    0.576221
# 2                                   -0.275446
# 3                                   -0.275446
# 4                                   -1.127113
#
#    7 How do you access the internet while shopping on-line?  \
# 0                                          -2.908068
# 1                                           1.290163
# 2                                          -1.508658
# 3                                          -1.508658
# 4                                           1.290163
#
#    8 Which device do you use to access the online shopping?  \
# ...

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=29)
x=pca.fit_transform(x)
x=pd.DataFrame(x)
x.shape
# Out:
# (269, 29)

# %% [markdown]
# ## Choosing Random State

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,classification_report
maxac=0
maxran=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    sam=DecisionTreeClassifier()
    sam.fit(x_train,y_train)
    pred=sam.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxac:
        maxac=acc
        maxran=i
print('max accuracy=',maxac,'ran state=',maxran)
# Out:
# max accuracy= 1.0 ran state= 3

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=maxran)

# %% [markdown]
# ## Model Selection

# %%
#Decision Tree

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
dtc_clas=classification_report(y_test,pred)
print(dtc_clas)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         5
#            6       1.00      1.00      1.00         8
#            7       1.00      1.00      1.00         4
#
#     accuracy                           1.00        81
#    macro avg       1.00      1.00      1.00        81
# weighted avg       1.00      1.00      1.00        81

# %%
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
pred=rfc.predict(x_test)
rfc_clas=classification_report(y_test,pred)
print(rfc_clas)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         5
#            6       1.00      1.00      1.00         8
#            7       1.00      1.00      1.00         4
#
#     accuracy                           1.00        81
#    macro avg       1.00      1.00      1.00        81
# weighted avg       1.00      1.00      1.00        81

# %%
# Support Vectors

# %%
from sklearn.svm import SVC
sup=SVC()
sup.fit(x_train,y_train)
pred=sup.predict(x_test)
sv_clas=classification_report(y_test,pred)
print(sv_clas)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         5
#            6       1.00      1.00      1.00         8
#            7       1.00      1.00      1.00         4
#
#     accuracy                           1.00        81
#    macro avg       1.00      1.00      1.00        81
# weighted avg       1.00      1.00      1.00        81

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(dtc,x,y,cv=3).mean())
print(cross_val_score(rfc,x,y,cv=3).mean())
print(cross_val_score(sup,x,y,cv=3).mean())
# Out:
# 0.9703703703703703
# 1.0
# 1.0

# %% [markdown]
# ### Random Forrest and Support vectors is giving the best model.

# %% [markdown]
# ### No need to use Hyper parameters also because already the model is giving 100% accuracy.
