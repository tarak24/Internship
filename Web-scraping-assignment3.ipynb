# %% [markdown]
# # WEB SCRAPING ASSIGNMENT 3

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver.exe")
# Out:
# <ipython-input-170-0af43046ad15>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver.exe")

# %% [markdown]
# ## Q1

# %%
driver.get('https://www.amazon.in/')

# %%
search_job=driver.find_element_by_xpath("//*[@id='twotabsearchtextbox']")
search_job.send_keys('guitar')
# Out:
# <ipython-input-4-fd137a7735f5>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("//*[@id='twotabsearchtextbox']")

# %%
from selenium.common.exceptions import NoSuchElementException
import time
try:
    search_btn=driver.find_element_by_xpath("//*[@id='nav-search-submit-button']")
    time.sleep(3)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-5-a54ae6bdc7a1>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='nav-search-submit-button']")

# %% [markdown]
# ## Q2

# %%
driver.get(driver.current_url)

# %%
title=[]
rati=[]
price=[]
br_name=[]
no_of_rating=[]
deliv=[]
url=[]
det=[]
for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
    url.append(i.get_attribute("href"))
# Out:
# <ipython-input-7-9ea627c56e8e>:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):

# %%
url
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A100976119ONHKLJMFAMG&url=%2FKadence-Slowhand-Premium-Acoustic-Instrument%2Fdp%2FB077SZ667X%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Dguitar%26qid%3D1639084948%26sr%3D8-1-spons%26psc%3D1%26smid%3DAM04Z7MH4HSDD&qualifier=1639084948&id=8290643164819239&widgetName=sp_atf',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A09549623MPFN6NPOQ4P4&url=%2FJuarez-Acoustic-Cutaway-038C-Strings%2Fdp%2FB017NPCSLI%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Dguitar%26qid%3D1639084948%26sr%3D8-2-spons%26psc%3D1&qualifier=1639084948&id=8290643164819239&widgetName=sp_atf',
# ...

# %%
for i in url:
    driver.get(i)
    time.sleep(3)
    # Fetching Name of product
    try:
        title_tag=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[6]/div[3]/div[4]/div[1]/div/h1/span")
        title.append(title_tag.text)
    except:
        title.append('-')
    # Fetching Brand name
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='productOverview_feature_div']/div/table/tbody/tr[1]/td[2]/span")
        br_name.append(title_tag.text)
    except:
        br_name.append('-')
    # Fetching Rating
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='a-popover-content-4']/div/div/div/div[1]/span")
        rati.append(title_tag.text)
    except:
        rati.append('-')
    # Fetching Number of ratings
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='acrCustomerReviewText']")
        no_of_rating.append(title_tag.text)
    except:
        no_of_rating.append('-')
    # Fetching price
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='priceblock_ourprice']")
        price.append(title_tag.text)
    except:
        price.append('-')
    # Fetching Expected Delivery
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='ddmDeliveryMessage']/b")
        deliv.append(title_tag.text)
    except:
        deliv.append('-')
    # Fetching other details
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='feature-bullets']/ul/li[1]/span")
        det.append(title_tag.text)
    except:
        det.append('-')
# Out:
# <ipython-input-9-e497b62e689b>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[6]/div[3]/div[4]/div[1]/div/h1/span")
# <ipython-input-9-e497b62e689b>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//*[@id='productOverview_feature_div']/div/table/tbody/tr[1]/td[2]/span")
# <ipython-input-9-e497b62e689b>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//*[@id='a-popover-content-4']/div/div/div/div[1]/span")
# <ipython-input-9-e497b62e689b>:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//*[@id='acrCustomerReviewText']")
# ...

# %%
try:
    search_btn=driver.find_element_by_xpath("//*[@id='nav-search-submit-button']")
    time.sleep(3)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
driver.get(driver.current_url)
next1=driver.find_element_by_xpath("//*[@id='search']/div[1]/div[1]/div/span[3]/div[2]/div[66]/span/div/div/ul/li[7]/a")
next1.click()
driver.get(driver.current_url)
url1=[]
for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
    url1.append(i.get_attribute("href"))
for i in url1:
    driver.get(i)
    time.sleep(3)
    # Fetching Name of product
    try:
        title_tag=driver.find_element_by_xpath("//h1[@class='a-size-large product-title-word-break']")
        title.append(title_tag.text)
    except:
        title.append('-')
    # Fetching Brand name
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='productOverview_feature_div']/div/table/tbody/tr[1]/td[2]/span")
        br_name.append(title_tag.text)
    except:
        br_name.append('-')
    # Fetching Rating
    try:
        title_tag=driver.find_element_by_xpath("/html/body/div[5]/div/div[1]/div/div/div/div/div[1]/span")
        rati.append(title_tag.text)
    except:
        rati.append('-')
    # Fetching Number of ratings
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='acrCustomerReviewText']")
        no_of_rating.append(title_tag.text)
    except:
        no_of_rating.append('-')
    # Fetching price
    try:
        title_tag=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[6]/div[3]/div[1]/div[3]/div/div/div/form/div/div/div/div/div[1]/div/span[1]")
        price.append(title_tag.text)
    except:
        price.append('-')
    # Fetching Expected Delivery
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='ddmDeliveryMessage']/b")
        deliv.append(title_tag.text)
    except:
        deliv.append('-')
    # Fetching other details
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='feature-bullets']/ul/li[1]/span")
        det.append(title_tag.text)
    except:
        det.append('-')
# Out:
# <ipython-input-10-e3420d005ac0>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='nav-search-submit-button']")
# <ipython-input-10-e3420d005ac0>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next1=driver.find_element_by_xpath("//*[@id='search']/div[1]/div[1]/div/span[3]/div[2]/div[66]/span/div/div/ul/li[7]/a")
# <ipython-input-10-e3420d005ac0>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
# <ipython-input-10-e3420d005ac0>:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//h1[@class='a-size-large product-title-word-break']")
# ...

# %%
prod=pd.DataFrame({})
prod['Price']=price
prod['brand']=br_name
prod['number_of_ratings']=no_of_rating
prod['delivery']=deliv
prod['details']=det
prod
# Out:
#          Price      brand number_of_ratings           delivery  \
# 0            -    Kadence       300 ratings  Wednesday, Dec 15
# 1    ₹2,649.00     Juârez    14,145 ratings    Tuesday, Dec 14
# 2    ₹5,299.00    Kadence     1,225 ratings  Wednesday, Dec 15
# 3            -    Kadence       782 ratings  Wednesday, Dec 15
# 4            -     Intern     8,364 ratings  Wednesday, Dec 15
# ..         ...        ...               ...                ...
# 129  ₹5,979.00     JUAREZ        21 ratings  Wednesday, Dec 15
# 130  ₹6,059.00     JUAREZ        29 ratings   Thursday, Dec 16
# 131  ₹2,190.00     Juârez       218 ratings   Thursday, Dec 16
# 132          -  Blueberry        16 ratings     Friday, Dec 17
# 133          -    Kadence       782 ratings  Wednesday, Dec 15
#
#                                                details
# 0    ACOUSTIC-ELECTRIC GUITAR: Kadence Slowhand sem...
# 1    Black Glossy Finish, Number of Frets: 18, Acou...
# ...

# %% [markdown]
# # Q3

# %%
driver.get('https://www.google.com/imghp?hl=en')

# %% [markdown]
# ### Fruits Scraping

# %%
search_job=driver.find_element_by_xpath("//*[@id='sbtc']/div[2]/div[2]/input")
search_job.send_keys('fruits')
# Out:
# <ipython-input-20-0c75128eb1f8>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("//*[@id='sbtc']/div[2]/div[2]/input")

# %%
from selenium.common.exceptions import NoSuchElementException
import time
try:
    search_btn=driver.find_element_by_xpath("//*[@id='sbtc']/button")
    time.sleep(3)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-21-765ecab40a32>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='sbtc']/button")

# %%
driver.get(driver.current_url)

# %%
l1=[]
ima1=driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
for i in ima1:
    time.sleep(1)
    a=i.get_attribute('src')
    l1.append(a)
l1=l1[:100]
l1
# Out:
# <ipython-input-23-f0a5b094fa08>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ima1=driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %% [markdown]
# ### Scraping Cars

# %%
driver.get('https://www.google.com/imghp?hl=en')
search_job=driver.find_element_by_xpath("//*[@id='sbtc']/div[2]/div[2]/input")
search_job.send_keys('cars')
# Out:
# <ipython-input-42-240264e7f8ce>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("//*[@id='sbtc']/div[2]/div[2]/input")

# %%
from selenium.common.exceptions import NoSuchElementException
import time
try:
    search_btn=driver.find_element_by_xpath("//*[@id='sbtc']/button")
    time.sleep(3)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-43-765ecab40a32>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='sbtc']/button")

# %%
l2=[]
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
    time.sleep(2)
    a=i.get_attribute('src')
    l2.append(a)
l2=l2[:100]
l2
# Out:
# <ipython-input-44-97b4fba2b890>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %% [markdown]
# ### Scraping Machine Learning

# %%
driver.get('https://www.google.com/imghp?hl=en')
search_job=driver.find_element_by_xpath("//*[@id='sbtc']/div[2]/div[2]/input")
search_job.send_keys('Machine Learning')
# Out:
# <ipython-input-46-df3eb6ce2576>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("//*[@id='sbtc']/div[2]/div[2]/input")

# %%
from selenium.common.exceptions import NoSuchElementException
import time
try:
    search_btn=driver.find_element_by_xpath("//*[@id='sbtc']/button")
    time.sleep(3)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-47-765ecab40a32>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='sbtc']/button")

# %%
l3=[]
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
    time.sleep(2)
    a=i.get_attribute('src')
    l3.append(a)
l3=l3[:100]
l3
# Out:
# <ipython-input-48-1140b5ba81a5>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/png;base64,...',
#  'data:image/png;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/png;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/png;base64,...',
#  'data:image/png;base64,...',
#  'data:image/png;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTba5qkPbfxaExGGfEhcujsY708WyfHopDV8w&usqp=CAU',
# ...

# %% [markdown]
# ## Q4

# %%
driver.get('https://www.flipkart.com/')
search_job=driver.find_element_by_xpath("//*[@id='container']/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
search_job.send_keys('Oneplus Nord pixel 4A')
# Out:
# <ipython-input-458-5fe23cd61fe1>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("//*[@id='container']/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

# %%
import time
try:
    search_btn=driver.find_element_by_xpath("//*[@id='container']/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
    time.sleep(3)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-459-8e2a181b8710>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='container']/div/div[1]/div[1]/div[2]/div[2]/form/div/button")

# %%
title=[]
url=[]
price=[]
br_name=[]
col=[]
ram=[]
stor=[]
pcam=[]
scam=[]
dis_s=[]
disres=[]
proc=[]
procore=[]
bat=[]
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    url.append(i.get_attribute("href"))
    try:
        title_tag=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']")
        bat.append(title_tag.text)
    except:
        bat.append('-')
    #try:
      #  title_tag=driver.find_elements_by_xpath("//*[@id='container']/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]/div[1]/div[3]/ul/li[2]")
     #   disres.append(title_tag.text)
    #except:
     #   disres.append('-')
    #try:
      #  title_tag=driver.find_elements_by_xpath("//*[@id='container']/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]/div[1]/div[3]/ul/li[1]")
     #   ram.append(title_tag.text)
    #except:
     #   ram.append('-')
    #try:
        #title_tag=driver.find_elements_by_xpath("//*[@id='container']/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]/div[1]/div[3]/ul/li[3]")
       # pcam.append(title_tag.text)
     #except:
      #  pcam.append('-')
# Out:
# <ipython-input-460-438297a665c2>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
# <ipython-input-460-438297a665c2>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//ul[@class='_1xgFaf']")

# %%
for i in url:
    driver.get(i)
    time.sleep(3)
    
    
    
    try:
        title_tag=driver.find_element_by_xpath("//span[@class='B_NuCI']")
        title.append(title_tag.text)
    except:
        title.append('-')
    
    try:
        title_tag=driver.find_element_by_xpath("//td[@class='URwL2w col col-9-12']")
        br_name.append(title_tag.text)
    except:
        br_name.append('-')
    
    try:
        title_tag=driver.find_element_by_xpath("//td[@class='URwL2w col col-9-12']")
        col.append(title_tag.text)
    except:
        col.append('-')
    
    try:
        title_tag=driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        price.append(title_tag.text)
    except:
        price.append('-')
    
    
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='container']/div/div[3]/div[1]/div[2]/div[8]/div[4]/div/div[2]/div[1]/div[3]/table/tbody/tr[1]/td[2]/ul/li")
        proc.append(title_tag.text)
    except:
        proc.append('-')
    
    try:
        title_tag=driver.find_element_by_xpath("//*[@id='container']/div/div[3]/div[1]/div[2]/div[8]/div[4]/div/div[2]/div[1]/div[3]/table/tbody/tr[2]/td[2]/ul/li")
        procore.append(title_tag.text)
    except:
        procore.append('-')
# Out:
# <ipython-input-461-fdf5fc1fa618>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//span[@class='B_NuCI']")
# <ipython-input-461-fdf5fc1fa618>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//td[@class='URwL2w col col-9-12']")
# <ipython-input-461-fdf5fc1fa618>:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//td[@class='URwL2w col col-9-12']")
# <ipython-input-461-fdf5fc1fa618>:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
# <ipython-input-461-fdf5fc1fa618>:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
mob=pd.DataFrame({})
mob['Battery']=bat
mob['Name']=title
mob['Brand']=br_name
mob['Colour']=col
mob['Price']=price
mob['Processor']=proc
mob
# Out:
#    Battery                                               Name  \
# 0        -         ringme Reno Plus (Blue, 16 GB)  (2 GB RAM)
# 1        -          ringme Reno Plus (Red, 16 GB)  (2 GB RAM)
# 2        -      LAVA Pixel V2 Plus (Black, 16 GB)  (2 GB RAM)
# 3        -      LAVA Pixel V2 Plus (White, 32 GB)  (3 GB RAM)
# 4        -      LAVA Pixel V2 Plus (Black, 32 GB)  (3 GB RAM)
# 5        -  SAMSUNG Galaxy S10 Plus (Ceramic White, 1 TB) ...
# 6        -  Phicomm Clue 3 Plus VoLTE (Gold, 16 GB)  (2 GB...
# 7        -                                                  -
# 8        -  I Kall K 8 NEw / K-8Plus (Red, 16 GB)  (2 GB RAM)
# 9        -  Micromax Bharat 4 Plus (Black, 16 GB)  (2 GB RAM)
# 10       -  KARBONN Titanium S9 plus (Blue, 32 GB)  (3 GB ...
# 11       -           Nokia 5.1 Plus (Blue, 64 GB)  (6 GB RAM)
# 12       -   Zopo Flash X Plus (Rose Gold, 32 GB)  (3 GB RAM)
# 13       -  Micromax CANVAS 2 PLUS (jet black, 32 GB)  (3 ...
#
# ...

# %% [markdown]
# ## Q5

# %%
driver.get('https://www.google.com/maps/@14.4568711,79.9975909,15z')

# %%
search_job=driver.find_element_by_xpath("//*[@id='searchboxinput']")
search_job.send_keys('Nellore')
# Out:
# <ipython-input-70-b568f5f27592>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("//*[@id='searchboxinput']")

# %%
try:
    search_btn=driver.find_element_by_xpath("//*[@id='searchbox-searchbutton']")
    time.sleep(3)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-71-ebeffa169224>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='searchbox-searchbutton']")

# %%
driver.get(driver.current_url)

# %%
url=driver.current_url
url
# Out:
# 'https://www.google.com/maps/place/Nellore,+Andhra+Pradesh/@14.4568711,79.9975909,15z/data=!4m5!3m4!1s0x3a4c8cca0e958771:0xd3036c2025161f55!8m2!3d14.4425987!4d79.986456'

# %%
ind=url.find('@')
ind
# Out:
# 58

# %%
sr=url[ind+1:]
sr
# Out:
# '14.4568711,79.9975909,15z/data=!4m5!3m4!1s0x3a4c8cca0e958771:0xd3036c2025161f55!8m2!3d14.4425987!4d79.986456'

# %%
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start
ind1=find_nth(sr,',',2)

# %%
lanlon=sr[:ind1]
print('Latitude and Longitude:',lanlon)
# Out:
# Latitude and Longitude: 14.4568711,79.9975909

# %% [markdown]
# ## Q6

# %%
driver.get('https://trak.in/')

# %%
try:
    search_btn=driver.find_element_by_xpath("//*[@id='main-navigation']/li[8]/a")
    time.sleep(2)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-442-f1ee4c82de57>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='main-navigation']/li[8]/a")

# %%
driver.get(driver.current_url)

# %%
try:
    search_btn=driver.find_element_by_xpath("//*[@id='menu-item-51510']/a")
    time.sleep(2)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-444-df1fdbe885e4>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='menu-item-51510']/a")

# %%
date=[]
star=[]
indu=[]
sub=[]
city=[]
inves_name=[]
inves_type=[]
amount=[]
title_tag=driver.find_elements_by_class_name("column-1")
for i in title_tag:
    try:
        date.append(i.text)
    except:
        date.append('-')
        
title_tag=driver.find_elements_by_class_name("column-2")
for i in title_tag:
    try:
        star.append(i.text)
    except:
        star.append('-')
        
title_tag=driver.find_elements_by_class_name("column-3")
for i in title_tag:
    try:
        indu.append(i.text)
    except:
        indu.append('-')
        
title_tag=driver.find_elements_by_class_name("column-4")
for i in title_tag:
    try:
        sub.append(i.text)
    except:
        sub.append('-')
        
title_tag=driver.find_elements_by_class_name("column-5")
for i in title_tag:
    try:
        city.append(i.text)
    except:
        city.append('-')
        
title_tag=driver.find_elements_by_class_name("column-6")
for i in title_tag:
    try:
        inves_name.append(i.text)
    except:
        inves_name.append('-')
        
title_tag=driver.find_elements_by_class_name("column-7")
for i in title_tag:
    try:
        inves_type.append(i.text)
    except:
        inves_type.append('-')
        
title_tag=driver.find_elements_by_class_name("column-8")
for i in title_tag:
    try:
        amount.append(i.text)
    except:
        amount.append('-')
# Out:
# <ipython-input-445-21933b507495>:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("column-1")
# <ipython-input-445-21933b507495>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("column-2")
# <ipython-input-445-21933b507495>:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("column-3")
# <ipython-input-445-21933b507495>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("column-4")
# <ipython-input-445-21933b507495>:37: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("column-5")
# ...

# %%
### November month's funding deals
date=date[46:57]
star=star[46:57]
indu=indu[46:57]
sub=sub[46:57]
city=city[46:57]
inves_name=inves_name[46:57]
inves_type=inves_type[46:57]
amount=amount[46:57]

# %%
fund=pd.DataFrame({})
fund['Date']=date
fund['Startup']=star
fund['Industry']=indu
fund['Sub Vertical']=sub
fund['City']=city
fund['Investment name']=inves_name
fund['Investment type']=inves_type
fund['Amount']=amount
fund
# Out:
#    Date     Startup         Industry        Sub Vertical  \
# 0
# 1     1  30/11/2020         Codingal             EduTech
# 2     2  30/11/2020             CRED  Financial Services
# 3     3  29/11/2020          Bira 91   Food and Beverage
# 4     4  27/11/2020          Chumbak           Lifestyle
# 5     5  25/11/2020          Cityflo      Transportation
# 6     6  25/11/2020           Shipsy                SaaS
# 7     7  25/11/2020        Unacademy             Edutech
# 8     8  24/11/2020         Cashfree             FinTech
# 9     9  30/11/2020       Credgenics             Fintech
# 10   10  23/11/2020  Country Delight          Dairy Tech
#
#                                                  City Investment name  \
# 0
# 1                              Online coding platform       Bengaluru
# 2                       Credit Card Behavior Services       Bengaluru
# 3                                          Craft Beer       New Delhi
# ...

# %% [markdown]
# ## Q7

# %%
driver.get('https://www.digit.in/')

# %%
try:
    search_btn=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[2]/a/img")
    time.sleep(2)
    search_btn.click()
except NoSuchElementException as e:
    print('Exception Raise :',e)
# Out:
# <ipython-input-416-3868e5eec4d6>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[2]/a/img")

# %%
driver.get(driver.current_url)

# %%
from selenium.webdriver.common.keys import Keys
search_job=driver.find_element_by_xpath("//*[@id='globalPageSearchText']")
search_job.send_keys('best gaming laptops')
search_job.send_keys(Keys.ENTER)
# Out:
# <ipython-input-418-3a05e6db788e>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("//*[@id='globalPageSearchText']")

# %%
driver.get(driver.current_url)

# %%
title=[]
price=[]
desc=[]
url=[]
for i in driver.find_elements_by_xpath("//div[@class='searchPage']/a"):
    time.sleep(1)
    url.append(i.get_attribute("href"))
# Out:
# <ipython-input-420-bf2d47f2192a>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='searchPage']/a"):

# %%
for i in url:
    driver.get(i)
    time.sleep(3)
    # Fetching Name of product
    try:
        title_tag=driver.find_element_by_xpath("//div[@class='heading-wraper']/h1")
        title.append(title_tag.text)
    except:
        title.append('-')
    # Fetching Price
    try:
        title_tag=driver.find_element_by_xpath("//div[@class='price']/strong")
        price.append(title_tag.text)
    except:
        price.append('-')
    # Fetching Processor
    try:
        title_tag=driver.find_element_by_xpath("//div[@class='para_container']/p")
        desc.append(title_tag.text)
    except:
        desc.append('-')
# Out:
# <ipython-input-421-2ff172c5170b>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//div[@class='heading-wraper']/h1")
# <ipython-input-421-2ff172c5170b>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//div[@class='price']/strong")
# <ipython-input-421-2ff172c5170b>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//div[@class='para_container']/p")

# %%
prod=pd.DataFrame({})
prod['Title']=title
prod['Price']=price
prod['Description']=desc
prod
# Out:
#                                                Title      Price  \
# 0                                 Asus G750JX-CV069P  ₹ 149,999
# 1                                      Lenovo G50-30   ₹ 25,694
# 2                                  HP Envy 15-k006tx   ₹ 80,510
# 3                                  ASUS ROG Flow x13  ₹ 154,990
# 4                        HP Envy dv6-7206tx notebook   ₹ 65,705
# 5                                Dell Vostro 15 3500   ₹ 38,489
# 6  ASUS G53J - A 3D gamer's delight but we want more  ₹ 112,499
# 7                       Samsung Series 9 (NP-900X3C)          -
# 8                              Sony PlayStation Vita   ₹ 24,990
# 9                        Asus GTX980 Matrix Platinum   ₹ 52,000
#
#                                          Description
# 0  Another, no-holds barred, uninterrupted gaming...
# 1  The Lenovo G series of laptops are aimed at bu...
# 2  Another heavy duty gaming laptop that bludgeon...
# 3
# ...

# %% [markdown]
# ## Q8

# %%
driver.get('https://www.forbes.com/billionaires/')

# %%
rank=[]
name=[]
net=[]
age=[]
con=[]
sor=[]
ind=[]

# %%
title_tag=driver.find_elements_by_class_name("rank")
for i in title_tag:
    try:
        rank.append(i.text)
    except:
        rank.append('-')
        
title_tag=driver.find_elements_by_class_name("personName")
for i in title_tag:    
    try:
        name.append(i.text)
    except:
        name.append('-')
        
title_tag=driver.find_elements_by_class_name("netWorth")
for i in title_tag:
    try:
        net.append(i.text)
    except:
        net.append('-')
        
title_tag=driver.find_elements_by_class_name("age")
for i in title_tag:
    try:
        age.append(i.text)
    except:
        age.append('-')
        
title_tag=driver.find_elements_by_class_name("countryOfCitizenship")
for i in title_tag:
    try:
        con.append(i.text)
    except:
        con.append('-')
        
title_tag=driver.find_elements_by_class_name("source")
for i in title_tag:
    try:
        sor.append(i.text)
    except:
        sor.append('-')
        
title_tag=driver.find_elements_by_class_name("category")
for i in title_tag:
    try:
        ind.append(i.text)
    except:
        ind.append('-')
# Out:
# <ipython-input-194-abf81919c81f>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("rank")
# <ipython-input-194-abf81919c81f>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("personName")
# <ipython-input-194-abf81919c81f>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("netWorth")
# <ipython-input-194-abf81919c81f>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("age")
# <ipython-input-194-abf81919c81f>:29: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_class_name("countryOfCitizenship")
# ...

# %%
forb=pd.DataFrame({})
forb['Rank']=rank
forb['Name']=name
forb['Net_worth']=net
forb['Age']=age
forb['country']=con
forb['source']=sor
forb['industry']=ind
forb
# Out:
#      Rank                      Name  Net_worth  Age              country  \
# 0    RANK                      NAME  NET WORTH  AGE  COUNTRY / TERRITORY
# 1      1.                Jeff Bezos     $177 B   57        United States
# 2      2.                 Elon Musk     $151 B   49        United States
# 3      3.  Bernard Arnault & family     $150 B   72               France
# 4      4.                Bill Gates     $124 B   65        United States
# ..    ...                       ...        ...  ...                  ...
# 196  195.           Harry Triguboff    $11.2 B   88            Australia
# 197  197.     Leonid Fedun & family    $11.1 B   65               Russia
# 198  197.                 Eyal Ofer    $11.1 B   70               Israel
# 199  197.              Evan Spiegel    $11.1 B   30        United States
# 200  200.     Luis Carlos Sarmiento      $11 B   88             Colombia
#
#                     source               industry
# ...

# %% [markdown]
# ## Q9

# %%
driver.get('https://www.youtube.com/')

# %%
search_job=driver.find_element_by_xpath("/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input")
search_job.send_keys("rrr trailer hindi")
# Out:
# <ipython-input-277-676cf7bdae15>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input")

# %%
search_btn=driver.find_element_by_xpath("//*[@id='search-icon-legacy']")
search_btn.click()
# Out:
# <ipython-input-278-fa01406164a3>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='search-icon-legacy']")

# %%
driver.get(driver.current_url)

# %%
a=driver.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[1]/div[1]/ytd-thumbnail/a")
link=a.get_attribute("href")
driver.get(link)
# Out:
# <ipython-input-280-5ba58f05ddb1>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   a=driver.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[1]/div[1]/ytd-thumbnail/a")

# %%
com=[]
upvote=[]
tim=[]

# %%
title_tag=driver.find_elements_by_id("content-text")
title_tag=title_tag[:500]
for i in title_tag:
    try:
        com.append(i.text)
    except:
        com.append('-')
        
title_tag=driver.find_elements_by_id("vote-count-middle")
title_tag=title_tag[:500]
for i in title_tag:    
    try:
        upvote.append(i.text)
    except:
        upvote.append('-')
        
title_tag=driver.find_elements_by_xpath("//*[@id='header-author']/yt-formatted-string")
title_tag=title_tag[:500]
for i in title_tag:
    try:
        tim.append(i.text)
    except:
        tim.append('-')
# Out:
# <ipython-input-298-7b3c8aa4ecd9>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_id("content-text")
# <ipython-input-298-7b3c8aa4ecd9>:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_id("vote-count-middle")
# <ipython-input-298-7b3c8aa4ecd9>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//*[@id='header-author']/yt-formatted-string")

# %%
you=pd.DataFrame({})
you['Comment']=com
you['Upvotes']=upvote
you['Time']=tim
you
# Out:
#                                                Comment Upvotes  \
# 0    Faaad Dala Bhai 💥💥🔥🔥🔥 Ramcharan+NTR+Ajay = 100...     14K
# 1    Bahubali Director S.S Rajamouli ji always brin...     871
# 2    That transformation of ramcharan to \nram from...     519
# 3                     Jai ram charan anna super 👌👌💪🏼💪🏼      36
# 4    No hero can match the archery style like Ram C...     499
# ..                                                 ...     ...
# 495  For the uninitiated, Ram Charan & NTR dubbed t...     143
# 496  😱😱😱😱😱😱😱😱😱😱😱👌👌👌👌👌👌👌👌👌 no words. \nSouth film in...       1
# 497  2:46 tribute to Prabhu Shri Ram.....More power...       3
# 498                              freaked out damn it 🔥
# 499  Everything is so perfect. We are lucky to have...
#
#                       Time
# 0      2 days ago (edited)
# 1             12 hours ago
# 2             13 hours ago
# 3              4 hours ago
# 4             10 hours ago
# ..                     ...
# ...

# %% [markdown]
# ## Q10

# %%
driver.get('https://www.hostelworld.com/')

# %%
search_job=driver.find_element_by_id("search-input-field")
# Out:
# <ipython-input-386-ede4abe6f7a5>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_id("search-input-field")

# %%
search_job.send_keys("London")

# %%
search_btn=driver.find_element_by_xpath("//*[@id='predicted-search-results']/li[2]")
search_btn.click()
# Out:
# <ipython-input-388-ea4c032b2a8d>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='predicted-search-results']/li[2]")

# %%
search_btn=driver.find_element_by_xpath("//*[@id='search-button']")
search_btn.click()
# Out:
# <ipython-input-389-31a2d3b80dd0>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//*[@id='search-button']")

# %%
name=[]
dist=[]
rat=[]
tot=[]
dorm=[]
priv=[]
title_tag=driver.find_elements_by_xpath("//h2[@class='title title-6']")
for i in title_tag:
    try:
        name.append(i.text)
    except:
        name.append('-')
    
title_tag=driver.find_elements_by_xpath("//span[@class='description']")  
for i in title_tag:
    try:
        dist.append(i.text)
    except:
        dist.append('-')
    
title_tag=driver.find_elements_by_xpath("//div[@class='score orange big']")
for i in title_tag:
    try:
        rat.append(i.text)
    except:
        rat.append('-')
    
title_tag=driver.find_elements_by_xpath("//div[@class='reviews']")
for i in title_tag:
    try:
        tot.append(i.text)
    except:
        tot.append('-')
        

title_tag=driver.find_elements_by_xpath("//div[@class='price title-5']")
for i in title_tag:
    try:
        priv.append(i.text)
    except:
        priv.append('-')
# Out:
# <ipython-input-394-63526f6e2757>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//h2[@class='title title-6']")
# <ipython-input-394-63526f6e2757>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//span[@class='description']")
# <ipython-input-394-63526f6e2757>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//div[@class='score orange big']")
# <ipython-input-394-63526f6e2757>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_tag=driver.find_elements_by_xpath("//div[@class='reviews']")
# <ipython-input-394-63526f6e2757>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ...

# %%
url=[]
for i in driver.find_elements_by_xpath("//h2[@class='title title-6']/a"):
    url.append(i.get_attribute("href"))
# Out:
# <ipython-input-402-b9bc475de263>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//h2[@class='title title-6']/a"):

# %%
over=[]
for i in url:
    driver.get(i)
    time.sleep(3)
    
    try:
        title_tag=driver.find_element_by_xpath("//div[@class='content collapse-content']")
        over.append(title_tag.text)
    except:
        over.append('-')
# Out:
# <ipython-input-405-50ba82edffef>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title_tag=driver.find_element_by_xpath("//div[@class='content collapse-content']")

# %%
hote=pd.DataFrame({})
hote['Name']=name
hote['Distance from city centre']=dist
hote['Rating']=rat
hote['Total Reviews']=tot
hote['Overview']=over
hote
# Out:
#                                        Name         Distance from city centre  \
# 0                        London Backpackers  Hostel - 11.9km from city centre
# 1           Wombat's The City Hostel London   Hostel - 3.6km from city centre
# 2                             Selina Camden   Hostel - 5.5km from city centre
# 3                  St Christopher's Village   Hostel - 1.8km from city centre
# 4                          Astor Museum Inn   Hostel - 2.2km from city centre
# 5         Safestay London Elephant & Castle   Hostel - 1.7km from city centre
# 6              No.8 Willesden Hostel London    Hostel - 10km from city centre
# 7                      Urbany Hostel London   Hostel - 5.4km from city centre
# 8                          Generator London     Hostel - 3km from city centre
# 9                                  SoHostel     Hostel - 2km from city centre
# 10                  Smart Camden Inn Hostel   Hostel - 4.4km from city centre
# ...

# %% [markdown]
# ##                                                   ******* THE END *******
